# %%
OPEN AI API KEY- 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

# %%
cd "C:\Users\heysu\OneDrive\Desktop\essilor_project"
.\.venv\Scripts\streamlit.exe run app.py
